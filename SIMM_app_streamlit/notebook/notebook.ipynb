# %% [markdown]
# # Importar librerias a usar

# %%
import pandas as pd

# %% [markdown]
# # Cargamos los archivos historicos, que lee el BI

# %%
# Cargar los archivos CSV
df1 = pd.read_csv(r"C:\Users\1513873.ANDESBPO\ANDES BPO S.A.S\Juan Jose JR. Restrepo Rios - Fotodetecciones\2025\Datos_BI_gestiones\base_acuerdos_pago.csv")
df2 = pd.read_csv(r"C:\Users\1513873.ANDESBPO\ANDES BPO S.A.S\Juan Jose JR. Restrepo Rios - Fotodetecciones\2025\Datos_BI_gestiones\base_gestion_asesores.csv")
df3 = pd.read_csv(r"C:\Users\1513873.ANDESBPO\ANDES BPO S.A.S\Juan Jose JR. Restrepo Rios - Fotodetecciones\2025\Datos_BI_gestiones\base_id_gestion.csv")
df4 = pd.read_csv(r"C:\Users\1513873.ANDESBPO\ANDES BPO S.A.S\Juan Jose JR. Restrepo Rios - Fotodetecciones\2025\Datos_BI_gestiones\base_numero_documento.csv")

print("AP : ",df1.shape[0])
print("gestiones: ",df2.shape[0])
print("id_gestiones: ",df3.shape[0])
print("Documentos: ",df4.shape[0])

# %% [markdown]
# ## Estamos leyendo los archivos nuevos del proof, para luego concatenar con el historico

# %%
df5 = pd.read_csv(r"C:\Users\1513873.ANDESBPO\ANDES BPO S.A.S\Johan Felipe JG. Gómez Arango - SIMM\Gestiones\Gestiones Nuevo\Octubre\output\base_acuerdos_pago.csv")
df6 = pd.read_csv(r"C:\Users\1513873.ANDESBPO\ANDES BPO S.A.S\Johan Felipe JG. Gómez Arango - SIMM\Gestiones\Gestiones Nuevo\Octubre\output\base_gestion_asesores.csv")
df7 = pd.read_csv(r"C:\Users\1513873.ANDESBPO\ANDES BPO S.A.S\Johan Felipe JG. Gómez Arango - SIMM\Gestiones\Gestiones Nuevo\Octubre\output\base_id_gestion.csv")
df8 = pd.read_csv(r"C:\Users\1513873.ANDESBPO\ANDES BPO S.A.S\Johan Felipe JG. Gómez Arango - SIMM\Gestiones\Gestiones Nuevo\Octubre\output\base_numero_documento.csv")


print("Output New AP : ",df5.shape[0])
print("Output New gestiones: ",df6.shape[0])
print("Output New id_gestiones: ",df7.shape[0])
print("Output New Documentos: ",df8.shape[0])

# %% [markdown]
# # Concatenar

# %%
df_conca_ap = pd.concat([df1,df5])
df_conca_gestion = pd.concat([df2,df6])
df_conca_id_gest = pd.concat([df3,df7])
df_conca_documento = pd.concat([df4,df8])

print("Concatenado de AP: ",df_conca_ap.shape[0])
print("Concatenado de Gestiones: ",df_conca_gestion.shape[0])
print("Concatenado de Id Gestiones: ",df_conca_id_gest.shape[0])
print("Concatenado de Documentos: ",df_conca_documento.shape[0])

# %% [markdown]
# # Importacion de los nuevos archivos historicos, con la informacion actualizada

# %%
df_conca_ap.to_csv(r"C:\Users\1513873.ANDESBPO\ANDES BPO S.A.S\Juan Jose JR. Restrepo Rios - Fotodetecciones\2025\Datos_BI_gestiones\base_acuerdos_pago.csv", index=False)
df_conca_gestion.to_csv(r"C:\Users\1513873.ANDESBPO\ANDES BPO S.A.S\Juan Jose JR. Restrepo Rios - Fotodetecciones\2025\Datos_BI_gestiones\base_gestion_asesores.csv", index=False)
df_conca_id_gest.to_csv(r"C:\Users\1513873.ANDESBPO\ANDES BPO S.A.S\Juan Jose JR. Restrepo Rios - Fotodetecciones\2025\Datos_BI_gestiones\base_id_gestion.csv", index=False)
df_conca_documento.to_csv(r"C:\Users\1513873.ANDESBPO\ANDES BPO S.A.S\Juan Jose JR. Restrepo Rios - Fotodetecciones\2025\Datos_BI_gestiones\base_numero_documento.csv", index=False)

# %% [markdown]
# celda para borrar el txt de archivos procesados

# %%
with open(r"C:\Users\1513873.ANDESBPO\ANDES BPO S.A.S\Johan Felipe JG. Gómez Arango - SIMM\Gestiones\Gestiones Nuevo\Octubre\output\archivos_procesados.txt", 'w', encoding='utf-8') as f:
    f.write('')
# Out:
#   Cell In[2], line 1
#     celda para borrar el txt de archivos procesados
#           ^
# SyntaxError: invalid syntax
